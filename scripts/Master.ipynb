# %%
# --- Autoreload for Custom Modules ---

# %load_ext autoreload
# %autoreload 2

# %%
# --- Custom Imports

import pandas as pd
from snowflake_extract_1 import get_session, extract_orders, cache_frame
from normalize_2 import normalize, validate_rowwise
from group_payloads_3 import rows_to_payloads
from send_triplewhale_4 import send_orders

# %%
session = get_session()
raw = extract_orders(session)
cache_path = cache_frame(raw, "orders_line_items")
norm = normalize(raw)
val = validate_rowwise(norm)
payloads = rows_to_payloads(val)
metrics = send_orders(payloads, retry_failures=True)
print("CACHE:", cache_path)
print("RESULT:", metrics)
# Out:
# Warning: Dependency 'keyring' is not installed, cannot cache id token. You might experience multiple authentication pop ups while using ExternalBrowser/OAuth/MFA Authenticator. To avoid this please install keyring module using the following command:
#  pip install snowflake-connector-python[secure-local-storage]
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Going to open: https://dish.okta.com/app/snowflake/exk9ewak82R5btDoW2p7/sso/saml?SAMLRequest=pZJPc9owEMW%2Fikc925JFPCEaTMYJkynTpGXAoSk3YQtQLEuuVsbk21fmTyc9JJfeNNJb%2Fd7u29HtoVbBXliQRqcojggKhC5MKfU2Rc%2F5QzhEATiuS66MFil6E4BuxyPgtWpY1rqdnovfrQAX%2BI80sP4hRa3VzHCQwDSvBTBXsEX29MhoRBgHENZ5HDqXlCA9a%2BdcwzDuui7qBpGxW0wJIZjcYK%2FqJV%2FQO0TzOaOxxpnCqEvJwff0ASLG5KpHeIUnzM6Fd1KfRvAZZX0SAfua57Nw9mORoyC7dHdvNLS1sAth97IQz%2FPHkwHwDn4tM0riwTBqIez87EIaNVbuuRNK6ioCbbqN4pUoTN20ziMif8IbUWJlttIPbjpJUVPJ0r3O5vVVZiuyeFndJd3WJOp1WcfZci3Ey269SfKnBAarb%2BusQMHyEjPtY54CtGKq%2B3CdvyI0CckwpNd5fM1iwuggIkO6QsHEG5Sau2PlpYNSwi4yleNHZ7xp8F%2FTWByqG9HxakjnydpNzE%2FaXGMAg%2Fvg0Gl32JFux%2F81kRF%2B%2F9V5J7%2F7mKaTmVGyeAsejK25%2BzjFOIqPN7IMN0cpEzWXKitLKwB8mkqZ7t4K7yNFzrYC4fGJ%2Bu%2Fyj%2F8A&RelayState=ver%3A1-hint%3A9387093479561018-ETMsDgAAAZjsglxqABRBRVMvQ0JDL1BLQ1M1UGFkZGluZwEAABAAEBueDTDDXNj7u7vPBzMp3poAAACgyYsK9LJZVfjg6r%2BIE%2FfEMagOoi9phi6%2BM%2FPKtywVZzebE9YQthNI1bD06slKihprSWs%2F23Rv1jdvozc%2BBCzmUPlA8Pqog1uJtTmDw3QbPn%2FQTkebzddP%2FEHj1C%2BfhUxOgH3WAiC3AXRBnaYTs894kYzrMJMMCgLzdJwsmMp%2FNNdx5g1%2FpRapCXff7actlB3XtNdUjzyDR8OK9s%2Fa5MNkygAUYCPL8JDwu6wlsYx0b7xE9MlUyrA%3D to authenticate...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 raw = extract_orders(session)
#       3 cache_path = cache_frame(raw, "orders_line_items")
# ----> 4 norm = normalize(raw)
#       5 val = validate_rowwise(norm)
#       6 payloads = rows_to_payloads(val)
#
# File ~/Documents/TripleWhaleDev/scripts/normalize_2.py:47, in normalize(df)
#      44 out["currency"] = DEFAULT_CURRENCY
#      46 # created_at: local → UTC ISO Z
# ---> 47 out["created_at_utc"] = to_iso_utc_from_local(out.get("created_at"))
#      49 return out
#
# File ~/Documents/TripleWhaleDev/scripts/normalize_2.py:29, in to_iso_utc_from_local(s)
#      27     except Exception:
#      28         return np.nan
# ---> 29 return s.apply(conv)
#
# AttributeError: 'NoneType' object has no attribute 'apply'
