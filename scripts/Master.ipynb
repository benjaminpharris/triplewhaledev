# %%
# --- Autoreload for Custom Modules ---

# %load_ext autoreload
# %autoreload 2

# %%
# --- Custom Imports

import pandas as pd
from snowflake_extract_1 import get_session, extract_orders, cache_frame
from normalize_2 import normalize, validate_rowwise
from group_payloads_3 import rows_to_payloads
from send_triplewhale_4 import send_orders

# %%
session = get_session()
raw = extract_orders(session)
cache_path = cache_frame(raw, "orders_line_items")
norm = normalize(raw)
val = validate_rowwise(norm)
val.to_parquet('/Users/Ben.Pharris/Library/CloudStorage/GoogleDrive-ben.pharris@dish.com/My Drive/TW_Sends/sends.parquet')
# Out:
# Warning: Dependency 'keyring' is not installed, cannot cache id token. You might experience multiple authentication pop ups while using ExternalBrowser/OAuth/MFA Authenticator. To avoid this please install keyring module using the following command:
#  pip install snowflake-connector-python[secure-local-storage]
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Going to open: https://dish.okta.com/app/snowflake/exk9ewak82R5btDoW2p7/sso/saml?SAMLRequest=pZLBctowEIZfxaOeLckG2qDBZJzQTNwmKQOEprkJW4DGsuRoZQx9%2BgoTOukhufTmkb%2FVftp%2FR5f7SgU7YUEanaAIUxQInZtC6k2CHhc34QUKwHFdcGW0SNBBALocj4BXqmZp47Z6Jl4aAS7wF2lg3Y8ENVYzw0EC07wSwFzO5un9HYsxZbU1zuRGoTclH1dwAGGdNzyXFCC93ta5mhHSti1ue9jYDYkppYQOiaeOyKczv%2FdveoePCO0feU94fPrqdiX1aQQfaa1OELDbxWIaTn%2FMFyhIz6rXRkNTCTsXdidz8Ti7OwmAN%2Fi1TGMa9S5wA2HrZxfGuLZyx51QUpcYtGnXipciN1XdON8C%2By%2ByFgVRZiP9FLJJgupSFsNvevI96%2F3WL6un2%2F72a82v9veVmWoqouWBOzl7flo%2B7Mp%2BmuUoWJ5jjo8xZwCNyPQxXOePaDwI6TCkvUX0mQ36jMa4P6TPKJh4Qam56yrPLygkbLEpHe%2FMeF2Tv9JE7MuhaHl5Ec8GKzcxP%2BP6CwEw5Bg0Ou0O67rb8X9NZETeXvW6kw8%2BpmwyNUrmh%2BDG2Iq791OMcNSdyCJcdygTFZcqLQorAHyaSpn22grvkSBnG4HI%2BNT13%2BUf%2FwE%3D&RelayState=ver%3A1-hint%3A9387093479561018-ETMsDgAAAZkQf%2Bn6ABRBRVMvQ0JDL1BLQ1M1UGFkZGluZwEAABAAEAwdrrrlynzgW0o1jgD0JcIAAACgyLmZIEYew873gIXNQGb6ogOR27RIvWZ2FtMpx7yXei9kSVNmDtu%2F1oysI5UxKs1DqiQEXCFS0v85%2FsbrrrYgH4OhqUPkJ%2FFQKExpXFPeKZq8vzhg8iZIbzZ2uKy1by5hW6H0pe6wdJxepl5e92mg3dUbmaVjHFKb6MLoRuSDmaTxIpBag8pVgv5ueQHQJBuR65PY%2FLy8S9s%2BY5s1X0keCwAUxiF0NPhWg73tyEO9alXPlLa9lFM%3D to authenticate...

# %%
'''

payloads = rows_to_payloads(val)

metrics = send_orders(payloads, retry_failures=True)
print("CACHE:", cache_path)
print("RESULT:", metrics)
'''
# Out:
#   Cell In[4], line 1
#     '''
#     ^
# SyntaxError: incomplete input
